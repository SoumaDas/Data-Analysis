# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler

# %%
A = ['dog', 'dog', 'cat', 'dog', 'dog', 'bird', 'dog', 'dog', 'mouse', 'cat']
A
# Out:
# ['dog', 'dog', 'cat', 'dog', 'dog', 'bird', 'dog', 'dog', 'mouse', 'cat']

# %%
s1 = pd.Series(A, name = 'Animal')
s1
# Out:
# 0      dog
# 1      dog
# 2      cat
# 3      dog
# 4      dog
# 5     bird
# 6      dog
# 7      dog
# 8    mouse
# 9      cat
# Name: Animal, dtype: object

# %%
s1.replace(['dog', 'cat', 'bird','mouse'],[0,1,2,3])
# Out:
# C:\Users\SOUMA DAS\AppData\Local\Temp\ipykernel_8320\2684528509.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   s1.replace(['dog', 'cat', 'bird','mouse'],[0,1,2,3])
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# 5    2
# 6    0
# 7    0
# 8    3
# 9    1
# Name: Animal, dtype: int64

# %%
val, arg = s1.factorize()
print(val, arg)
# Out:
# [0 0 1 0 0 2 0 0 3 1] Index(['dog', 'cat', 'bird', 'mouse'], dtype='object')

# %%
df = pd.read_csv(r'data\iris.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
dff = pd.read_csv(r'data\tips.csv')
dff
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
pd.get_dummies(dff, dtype = int)
# Out:
#      total_bill   tip  size  sex_Female  sex_Male  smoker_No  smoker_Yes  \
# 0         16.99  1.01     2           1         0          1           0
# 1         10.34  1.66     3           0         1          1           0
# 2         21.01  3.50     3           0         1          1           0
# 3         23.68  3.31     2           0         1          1           0
# 4         24.59  3.61     4           1         0          1           0
# ..          ...   ...   ...         ...       ...        ...         ...
# 239       29.03  5.92     3           0         1          1           0
# 240       27.18  2.00     2           1         0          0           1
# 241       22.67  2.00     2           0         1          0           1
# 242       17.82  1.75     2           0         1          1           0
# 243       18.78  3.00     2           1         0          1           0
#
#      day_Fri  day_Sat  day_Sun  day_Thur  time_Dinner  time_Lunch
# ...

# %%
df1 = df.drop('species', axis = 1)

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
plt.figure()
x = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
plt.boxplot(x, showmeans = True)
print(type(x))
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
x1 = ss.fit_transform(x)
x1 = pd.DataFrame(x1)
x1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 x1 = ss.fit_transform(x)
#       2 x1 = pd.DataFrame(x1)
#       3 x1
#
# NameError: name 'ss' is not defined

# %%
plt.figure()
plt.boxplot(x1, showmeans = True)
plt.show()
