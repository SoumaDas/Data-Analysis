# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'data\iris.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.columns = ['sl', 'sw', 'pl', 'pw', 'sp'] #will rename the column names
df
# Out:
#       sl   sw   pl   pw         sp
# 0    5.1  3.5  1.4  0.2     setosa
# 1    4.9  3.0  1.4  0.2     setosa
# 2    4.7  3.2  1.3  0.2     setosa
# 3    4.6  3.1  1.5  0.2     setosa
# 4    5.0  3.6  1.4  0.2     setosa
# ..   ...  ...  ...  ...        ...
# 145  6.7  3.0  5.2  2.3  virginica
# 146  6.3  2.5  5.0  1.9  virginica
# 147  6.5  3.0  5.2  2.0  virginica
# 148  6.2  3.4  5.4  2.3  virginica
# 149  5.9  3.0  5.1  1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1 = df.drop('sp', axis = 1)
df2 = df1.corr()
print(type(df2))
print(df2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#           sl        sw        pl        pw
# sl  1.000000 -0.117570  0.871754  0.817941
# sw -0.117570  1.000000 -0.428440 -0.366126
# pl  0.871754 -0.428440  1.000000  0.962865
# pw  0.817941 -0.366126  0.962865  1.000000

# %%
plt.scatter(df1['sl'], df1['pl'])

# %%
df4 = df[['sl', 'pl']]
df4
# Out:
#       sl   pl
# 0    5.1  1.4
# 1    4.9  1.4
# 2    4.7  1.3
# 3    4.6  1.5
# 4    5.0  1.4
# ..   ...  ...
# 145  6.7  5.2
# 146  6.3  5.0
# 147  6.5  5.2
# 148  6.2  5.4
# 149  5.9  5.1
#
# [150 rows x 2 columns]

# %%
df5 =df4.sample(20)
df5
# Out:
#       sl   pl
# 117  7.7  6.7
# 13   4.3  1.1
# 107  7.3  6.3
# 97   6.2  4.3
# 137  6.4  5.5
# 138  6.0  4.8
# 143  6.8  5.9
# 72   6.3  4.9
# 111  6.4  5.3
# 18   5.7  1.7
# 53   5.5  4.0
# 129  7.2  5.8
# 52   6.9  4.9
# 130  7.4  6.1
# 55   5.7  4.5
# 34   4.9  1.5
# 56   6.3  4.7
# 16   5.4  1.3
# 133  6.3  5.1
# 14   5.8  1.2

# %%
dff = df5.sort_values(by = 'pl')
dff
# Out:
#       sl   pl
# 13   4.3  1.1
# 14   5.8  1.2
# 16   5.4  1.3
# 34   4.9  1.5
# 18   5.7  1.7
# 53   5.5  4.0
# 97   6.2  4.3
# 55   5.7  4.5
# 56   6.3  4.7
# 138  6.0  4.8
# 72   6.3  4.9
# 52   6.9  4.9
# 133  6.3  5.1
# 111  6.4  5.3
# 137  6.4  5.5
# 129  7.2  5.8
# 143  6.8  5.9
# 130  7.4  6.1
# 107  7.3  6.3
# 117  7.7  6.7

# %%
plt.plot(dff['sl'], dff['pl'])

# %%
plt.step(dff['sl'], dff['pl'])

# %%
plt.scatter(dff['sl'], dff['pl'])
